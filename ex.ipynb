# %%
import global_def as gd
import pandas as pd


lst = ['김밥천국@김밥', '김밥천국@라면', '김밥천국@돈까스', '빕스@스테이크', '빕스@립', '편의점@컵라면', '편의점@삼각김밥']
original_len = len(lst) #최초의 리스트 길이를 저장 (최초 데이터 개수)
hash_members = gd.list_to_hash(lst)

# 각 키에 대한 최대 길이를 구함 
max_length = max(len(v) for v in hash_members.values())

# 모든 리스트를 동일한 길이로 맞춤
for key in hash_members:
    hash_members[key].extend([None] * (max_length - len(hash_members[key])))

# 판다스 데이터프레임으로 변환
df = pd.DataFrame(dict(hash_members))
non_none_counts_per_column = df.notnull().sum() # 각 컬럼별로 None이 아닌 데이터 개수를 구함
total_non_none_count = non_none_counts_per_column.sum() # 모든 컬럼의 None이 아닌 데이터 개수를 구함
total_non_none_count

if original_len != total_non_none_count:
    print("WARNING: Data is not equal to original data, original data: " + str(original_len) + ", current data: " + str(total_non_none_count) + ", please check the data.")
else:
    print("Data is equal to original data, original list: " + str(original_len) + ", DataFrame: " + str(total_non_none_count))

df
# Out:
# Data is equal to original data, original list: 7, DataFrame: 7
#   김밥천국    빕스   편의점
# 0   김밥  스테이크   컵라면
# 1   라면     립  삼각김밥
# 2  돈까스  None  None

# %%
df
# Out:
#          死      유리      빛     약속   시크릿      로망     의리    달빛    의지    인연     극한
# 0       반함    마강마도     기광     요거    초보      제압  강도차승준   프릭커    방깍    잠양   니트언니
# 1      따구미      머머   해리포터    김가율   단요한     문안나   우드워드    살살    냥이    재원  원거리초보
# 2      쥐센세  찐따같은초보  광안리가자    황썬우  호두맥주    귀문킬러     보리    미나    순궁  None  사냥개고수
# 3       습관      반격     추해    극용랑   연탈토     휴지심    에스급    떡래    헤이  None     모도
# 4      김쭈닝     유천우     무현  제일궁다샙    꽃희      휴디     매쫑    꿀꺽   쁠레기  None   None
# 5       배구     라자바    아린의    승민지    응왜     허효찌     듀님    밤밤    붸츄  None   None
# 6       세겹      동탁    앙지은     배출  None     카디타    성용몬   꼬꼬닦   자몽리  None   None
# 7       피치      솔랭     이브     의뀨  None      홀릭   아가유나   고천득    넋니  None   None
# 8       주니    방어해제     레리    깅경태  None  배터지는콜라    파트하  할수없어   황창영  None   None
# 9       달링      첼채     칸포     가은  None      탐키    힐타치    동화   돔황쳐  None   None
# 10      초급      나비     으둥     제빔  None      싫어     체람   이경진  None  None   None
# 11     어멍네      콩치     설라     예리  None      앗쉐     방심    쩌리  None  None   None
# 12      소금   도둑김용수     어도    나나토  None      바니     고맡    빙글  None  None   None
# 13      하히      랫쥐    진도표     포맨  None      애틋     정연  None  None  None   None
# 14     해찬갓   사수이광민    명주르  비책듣기용  None    None     영준  None  None  None   None
# 15      풋볼      우웽     카드     어제  None    None   None  None  None  None   None
# 16  화니버프듣기      참젖     마기     급박  None    None   None  None  None  None   None
# 17    후지토라      제코    둘레길     상담  None    None   None  None  None  None   None
# 18      사기     이슬상   None   로빈달래  None    None   None  None  None  None   None
# 19      구탁      사숱   None    타라수  None    None   None  None  None  None   None
# 20      아이  보이면삼초캇   None    에디앙  None    None   None  None  None  None   None
# 21     김삐냥    알바코어   None     섬연  None    None   None  None  None  None   None
# 22      김숙     빙구업   None     뚱붕  None    None   None  None  None  None   None
# 23      신검    None   None     노숙  None    None   None  None  None  None   None
# 24     미여누    None   None     시하  None    None   None  None  None  None   None
# 25      렌쥬    None   None     호로  None    None   None  None  None  None   None
# 26      낙현    None   None    킴럼마  None    None   None  None  None  None   None
# 27   서포터니까    None   None    팍쿠니  None    None   None  None  None  None   None
# 28      치타    None   None     셔룩  None    None   None  None  None  None   None
# 29    화니버프    None   None   아가호랑  None    None   None  None  None  None   None
# 30      행적    None   None     뱀띠  None    None   None  None  None  None   None
# 31     후시딘    None   None    라임초  None    None   None  None  None  None   None
# 32     꽃서비    None   None    대학생  None    None   None  None  None  None   None
# 33   탐욕의이빨    None   None   화룡비보  None    None   None  None  None  None   None
# 34      탄뎅    None   None     유럽  None    None   None  None  None  None   None
# 35    마도문어    None   None     호랑  None    None   None  None  None  None   None
# 36      자신    None   None     신궁  None    None   None  None  None  None   None
# 37    None    None   None     비책  None    None   None  None  None  None   None
# 38    None    None   None     로우  None    None   None  None  None  None   None
# 39    None    None   None     네이  None    None   None  None  None  None   None
# 40    None    None   None     군주  None    None   None  None  None  None   None
# 41    None    None   None    아잇츄  None    None   None  None  None  None   None
# 42    None    None   None     석윤  None    None   None  None  None  None   None

# %%
import global_def as gd
import pandas as pd

lst
# Out:
# total_non_none_count: 7
# original_len: 7
# Success
#   김밥천국    빕스   편의점
# 0   김밥  스테이크   컵라면
# 1   라면     립  삼각김밥
# 2  돈까스  None  None

# %%
hash_members = {'김밥천국': ['김밥', '라면', '돈까스'], '빕스': ['스테이크', '립'], '편의점': ['컵라면', '삼각김밥']}
df = pd.DataFrame(dict(hash_members))
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 hash_members = {'김밥천국': ['김밥', '라면', '돈까스'], '빕스': ['스테이크', '립'], '편의점': ['컵라면', '삼각김밥']}
# ----> 2 df = pd.DataFrame(dict(hash_members))
#       3 df
#
# File c:\Users\rayno\miniconda3\Lib\site-packages\pandas\core\frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# File c:\Users\rayno\miniconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\rayno\miniconda3\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\rayno\miniconda3\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
import global_def as gd
lst = ['死1@반함', '유리@마강마도', '빛@기광 x', '유리@머머', '약속2@요거', '빛@해리포터', '시크릿@초보', '빛@광안리가자', '유리@찐따같은초보', '빛@추해', '로망@제압 X', '유리@반격', '의리2@강도차승준', '유리@유천우', '유리@라자바', '약속4@김가율(X)', '약속6@황썬우', '의리2@우드워드', '달빛@프릭커', '빛@무현', '의리2@보리', '약속6@극용랑', '약속3@제일궁다샙', '死@따구미 X', '달빛@살살', '유리@동탁', '의지@방깍', '死3@쥐센세', '약속6@승민지(X)', '로망@문안나', '달빛@미나', '빛@아린의', '死1@습관', '의지@냥이', '약속1@배출(X)', '死@김쭈닝3 X', '약속4@의뀨(X)', '死5@배구', '빛@앙지은', '死3@세겹', '약속6@깅경태', '약속3@가은', '약속@제빔', '死1@피치', '유리2@솔랭', '약속1@예리 X', '로망@귀문킬러', '약속1@나나토', '의리1@에스급', '빛@이브x', '인연@잠양', '극한@니트언니', '死3@주니', '빛@레리x', '극한@원거리초보', '약속4@포맨(x)', '死1@달링', '의리1@매쫑', '빛@칸포', '死1@초급', '로망@휴지심', '의지@순궁', '의리2@듀님', '약속@비책(듣기용)', '의지@헤이', '빛@으둥', '死1@어멍네', '약속1@어제', '死3@소금3', '의리1@성용몬', '달빛@떡래', '빛@설라X', '약속3@급박', '유리@방어해제', '약속1@상담', '유리@첼채', '약속3@로빈달래', '약속4@타라수', '死1@하히', '시크릿@단요한', '死4@해찬갓', '유리@나비', '死3@풋볼2 X', '로망@휴디', '死2@화니버프(듣기)', '약속2@에디앙(X)', '시크릿@호두맥주', '유리@콩치', '약속2@섬연', '유리@도둑김용수', '死5@후지토라', '약속4@뚱붕(X)', '약속4@노숙', '약속@시하', '의리2@아가유나', '의리2@파트하', '인연@재원', '약속2@호로', '약속6@킴럼마', '약속1@팍쿠니', '의리1@힐타치', '약속4@셔룩(x)', '빛@어도', '시크릿@연탈토', '빛@진도표', '약속2@아가호랑', '달빛@꿀꺽', '死1@사기', '약속3@뱀띠', '빛@명주르', '유리@랫쥐', '약속6@라임초', '로망@허효찌', '死5@구탁', '달빛@밤밤', '로망@카디타', '死5@아이', '死3@김삐냥', '극한@사냥개고수', '유리@사수이광민', '死5@김숙', '의리1@체람', '로망@홀릭X', '달빛@꼬꼬닦', '약속1@대학생', '약속2@화룡비보', '시크릿@꽃희', '유리@우웽', '유리@참젖', '달빛@고천득', '빛@카드', '달빛@할수없어', '유리1@제코', '약속1@유럽', '死3@신검', '의지@쁠레기X', '달빛@동화', '약속2@호랑', '유리@이슬상', '약속@신궁', '유리@사숱', '의지@붸츄X', '유리@보이면삼초캇', '빛@마기', '로망@배터지는콜라X', '의리1@방심', '달빛@이경진', '빛@둘레길', '유리@알바코어X', '의지@자몽리', '死4@미여누 X', '死3@렌쥬', '달빛@쩌리', '의지@넋니', '유리@빙구업', '00약속@비책', '의리2@고맡X', '로망@탐키x', '약속2@로우', '死5@낙현', '의지@황창영x', '의리1@정연X', '로망@싫어', '死5@서포터니까', '약속2@네이x', '로망@앗쉐', '로망@바니', '시크릿@응왜', '극한@모도', '약속2@군주', '의리2@영준', '달빛@빙글', '로망@애틋', '의지@돔황쳐X', '약속4@아잇츄', '약속1@석윤', '死4@치타X']

df = gd.create_hashed_df(lst)
def pretty_print_df(df):
    for column in df:
        non_null_rows = df[column].dropna()
        print(f"{column}: 참여인원 = {len(non_null_rows)}")
        print(non_null_rows.to_string(index=False), ' ')

pretty_print_df(df)
# Out:
# Data is equal to original data, original list: 177, DataFrame: 177
# 死: 참여인원 = 29
#     반함
#    따구미
#    쥐센세
#     습관
#    김쭈닝
#     배구
#     세겹
#     피치
#     주니
#     달링
#     초급
#    어멍네
#     소금
#     하히
#    해찬갓
#     풋볼
# 화니버프듣기
#   후지토라
#     사기
#     구탁
#     아이
#    김삐냥
#     김숙
#     신검
#    미여누
#     렌쥬
#     낙현
#  서포터니까
#     치타
# 유리: 참여인원 = 23
#   마강마도
#     머머
# 찐따같은초보
#     반격
#    유천우
#    라자바
#     동탁
#     솔랭
#   방어해제
#     첼채
#     나비
#     콩치
#  도둑김용수
#     랫쥐
#  사수이광민
#     우웽
#     참젖
#     제코
#    이슬상
#     사숱
# 보이면삼초캇
#   알바코어
#    빙구업
# 빛: 참여인원 = 18
#    기광
#  해리포터
# 광안리가자
#    추해
#    무현
#   아린의
#   앙지은
#    이브
#    레리
#    칸포
#    으둥
#    설라
#    어도
#   진도표
#   명주르
#    카드
#    마기
#   둘레길
# 약속: 참여인원 = 43
#    요거
#   김가율
#   황썬우
#   극용랑
# 제일궁다샙
#   승민지
#    배출
#    의뀨
#   깅경태
#    가은
#    제빔
#    예리
#   나나토
#    포맨
# 비책듣기용
#    어제
#    급박
#    상담
#  로빈달래
#   타라수
#   에디앙
#    섬연
#    뚱붕
#    노숙
#    시하
#    호로
#   킴럼마
#   팍쿠니
#    셔룩
#  아가호랑
#    뱀띠
#   라임초
#   대학생
#  화룡비보
#    유럽
#    호랑
#    신궁
#    비책
#    로우
#    네이
#    군주
#   아잇츄
#    석윤
# 시크릿: 참여인원 = 6
#   초보
#  단요한
# 호두맥주
#  연탈토
#   꽃희
#   응왜
# 로망: 참여인원 = 14
#     제압
#    문안나
#   귀문킬러
#    휴지심
#     휴디
#    허효찌
#    카디타
#     홀릭
# 배터지는콜라
#     탐키
#     싫어
#     앗쉐
#     바니
#     애틋
# 의리: 참여인원 = 15
# 강도차승준
#  우드워드
#    보리
#   에스급
#    매쫑
#    듀님
#   성용몬
#  아가유나
#   파트하
#   힐타치
#    체람
#    방심
#    고맡
#    정연
#    영준
# 달빛: 참여인원 = 13
#  프릭커
#   살살
#   미나
#   떡래
#   꿀꺽
#   밤밤
#  꼬꼬닦
#  고천득
# 할수없어
#   동화
#  이경진
#   쩌리
#   빙글
# 의지: 참여인원 = 10
#  방깍
#  냥이
#  순궁
#  헤이
# 쁠레기
#  붸츄
# 자몽리
#  넋니
# 황창영
# 돔황쳐
# 인연: 참여인원 = 2
# 잠양
# 재원
# 극한: 참여인원 = 4
#  니트언니
# 원거리초보
# 사냥개고수
#    모도
